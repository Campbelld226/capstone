# %% [markdown]
# # Visualizations

# %%
import pandas as pd
from Labeler import Labeler
import matplotlib.pyplot as plt 
import warnings
import seaborn as sns
pd.options.display.max_rows = 999
# warnings.filterwarnings('ignore')

# %% [markdown]
# ## Clustering Algorithms

# %%
l = Labeler(pd.read_csv('test/CoRoT-2b_1.7.csv'))
df = l.get_data()
df
# Out:
#            epoch    depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# 6   2.457920e+06  0.23830    0.952172        -0.003157         0.955861
# 7   2.457920e+06  0.24362    0.973429        -0.012427         0.958205
# 8   2.457920e+06  0.24084    0.962321        -0.018340         0.962640
# 9   2.457920e+06  0.23909    0.955328        -0.065769         0.963693
# 10  2.457920e+06  0.24673    0.985855        -0.054981         0.967835
# 11  2.457920e+06  0.24543    0.980661        -0.066648         0.973948
# 12  2.457920e+06  0.25555    1.021097        -0.023974         0.995871
# 13  2.457920e+06  0.26049    1.040836        -0.031286         1.014198
# 14  2.457920e+06  0.26211    1.047309        -0.038279         1.036414
# 15  2.457920e+06  0.26155    1.045071        -0.057778         1.044405
# 16  2.457920e+06  0.26832    1.072122        -0.022016         1.054834
# 17  2.457920e+06  0.27169    1.085588         0.002158         1.067594
# ...

# %% [markdown]
# ## Countplot of unique values

# %%
display(df['labels_desc'].value_counts())
fig = plt.figure(figsize=(8,5))
sns.countplot(x='labels_desc',data = df)
plt.title('Count of Unique Periods')
# Out:
# Bottom            34
# Downward Slope    14
# Pre-Transit       10
# Post-Transit       8
# Upward Slope       6
# Name: labels_desc, dtype: int64
# Text(0.5, 1.0, 'Count of Unique Periods')

# %% [markdown]
# ## Stats on Each Attribute

# %%
df = df[[x for x in df if x not in ['is_level', 'is_pos', 'is_neg', 'labels_int']]]
df.describe()
# Out:
#               epoch      depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# count  7.200000e+01  72.000000   72.000000        72.000000        72.000000
# mean   2.457920e+06   0.269782    1.077962        -0.000834         1.077605
# std    3.079645e-02   0.013991    0.055904         0.023902         0.055920
# min    2.457920e+06   0.238300    0.952172        -0.066648         0.955861
# 25%    2.457920e+06   0.260692    1.041645        -0.009200         1.037912
# 50%    2.457920e+06   0.277075    1.107104        -0.002337         1.105499
# 75%    2.457921e+06   0.279875    1.118292         0.011198         1.119228
# max    2.457921e+06   0.284710    1.137611         0.060095         1.133536
#
#        depth_prop_sma7  depth_prop_sma3_slope
# count        72.000000              72.000000
# mean          1.077377              -0.000355
# std           0.054786               0.007974
# min           0.961014              -0.022216
# ...

# %% [markdown]
# ## Scatter and Distribution Plot of Each Attribute

# %%
for index, col in enumerate(df):
    if df[col].dtype != (object):
        fig, ax = plt.subplots(1,2, figsize=(12, 5), tight_layout=1)
        plt.title(col)
        sns.scatterplot(x=range(len(df[col])), y=df[col], ax=ax[0])
        sns.distplot(df[col], ax=ax[1])
        fig.show()
# Out:
# /home/dylan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   import sys
