# %% [markdown]
# # Visualizations

# %%
import pandas as pd
from Labeler import Labeler
import matplotlib.pyplot as plt 
import warnings
import seaborn as sns
import random
pd.options.display.max_rows = 999
warnings.filterwarnings('ignore')

# %% [markdown]
# # Clustering Algorithms

# %% [markdown]
# ## HAT-P-23b

# %%
# Agglomerative
l1 = Labeler(pd.read_csv('test/HAT-P-23b_1.3.csv'))
l1.get_data()
agglom = l1.cluster_method(1)
l1.order_clusters(agglom)

# Spectral
l2 = Labeler(pd.read_csv('test/HAT-P-23b_1.3.csv'))
l2.get_data()
spectral = l2.cluster_method(2)
l2.order_clusters(spectral)

# K-Means
l3 = Labeler(pd.read_csv('test/HAT-P-23b_1.3.csv'))
l3.get_data()
kmeans = l3.cluster_method(3)
l3.order_clusters(kmeans)

# Graph clustering Methods
fig, ax = plt.subplots(1,3, figsize=(15,5), tight_layout=1)
ax[0].set(title="Agglomerative", xlabel="Epoch")
ax[1].set(title="Spectral", xlabel="Epoch")
ax[2].set(title="K-Means", xlabel="Epoch")
sns.scatterplot(x=range(len(l1.X['depth'])),
                    y=l1.X['depth'] * -1, hue=l1.X['labels_desc'], ax=ax[0])
sns.scatterplot(x=range(len(l2.X['depth'])),
                    y=l2.X['depth'] * -1, hue=l2.X['labels_desc'], ax=ax[1])
sns.scatterplot(x=range(len(l3.X['depth'])),
                    y=l3.X['depth'] * -1, hue=l3.X['labels_desc'], ax=ax[2])
fig.show()

print("Agglomerative Clustering Result:")
l1.classify()
print("\nSpectral Clustering Result:")
l2.classify()
print("\nK-Means Clustering Result:")
l3.classify()
# Out:
# Agglomerative Clustering Result:
# Confidence of transit:  90.00%
# Majority of checks passed, Transit highly probable.
#
# Spectral Clustering Result:
# Confidence of transit:  75.00%
# Checks passed fall within a middle range, transit probable but direct examination required.
#
# K-Means Clustering Result:
# Confidence of transit:  62.50%
# Checks passed fall within a lower range, transit possible but more analysis required.

# %% [markdown]
# ## CoRoT-2b - Distinct Transit

# %%
# Agglomerative
l1 = Labeler(pd.read_csv('test/CoRoT-2b_1.2.csv'))
l1.get_data()
agglom = l1.cluster_method(1)
l1.order_clusters(agglom)

# Spectral
l2 = Labeler(pd.read_csv('test/CoRoT-2b_1.2.csv'))
l2.get_data()
spectral = l2.cluster_method(2)
l2.order_clusters(spectral)

# K-Means
l3 = Labeler(pd.read_csv('test/CoRoT-2b_1.2.csv'))
l3.get_data()
kmeans = l3.cluster_method(3)
l3.order_clusters(kmeans)

# Graph clustering Methods
fig, ax = plt.subplots(1,3, figsize=(15,5), tight_layout=1)
ax[0].set(title="Agglomerative", xlabel="Epoch")
ax[1].set(title="Spectral", xlabel="Epoch")
ax[2].set(title="K-Means", xlabel="Epoch")
sns.scatterplot(x=range(len(l1.X['depth'])),
                    y=l1.X['depth'] * -1, hue=l1.X['labels_desc'], ax=ax[0])
sns.scatterplot(x=range(len(l2.X['depth'])),
                    y=l2.X['depth'] * -1, hue=l2.X['labels_desc'], ax=ax[1])
sns.scatterplot(x=range(len(l3.X['depth'])),
                    y=l3.X['depth'] * -1, hue=l3.X['labels_desc'], ax=ax[2])
fig.show()

print("Agglomerative Clustering Result:")
l1.classify()
print("\nSpectral Clustering Result:")
l2.classify()
print("\nK-Means Clustering Result:")
l3.classify()
# Out:
# Confidence of transit:  92.50%
# Majority of checks passed, Transit highly probable.
# Confidence of transit:  70.00%
# Checks passed fall within a lower range, transit possible but more analysis required.
# Confidence of transit:  80.00%
# Checks passed fall within a middle range, transit probable but direct examination required.

# %% [markdown]
# ## No Transit

# %%
# Agglomerative
l1 = Labeler(pd.read_csv('test/no_transit.csv'))
l1.get_data()
agglom = l1.cluster_method(1)
l1.order_clusters(agglom)

# Spectral
l2 = Labeler(pd.read_csv('test/no_transit.csv'))
l2.get_data()
spectral = l2.cluster_method(2)
l2.order_clusters(spectral)

# K-Means
l3 = Labeler(pd.read_csv('test/no_transit.csv'))
l3.get_data()
kmeans = l3.cluster_method(3)
l3.order_clusters(kmeans)

# Graph clustering Methods
fig, ax = plt.subplots(1,3, figsize=(15,5), tight_layout=1)
ax[0].set(title="Agglomerative", xlabel="Epoch")
ax[1].set(title="Spectral", xlabel="Epoch")
ax[2].set(title="K-Means", xlabel="Epoch")
sns.scatterplot(x=range(len(l1.X['depth'])),
                    y=l1.X['depth'] * -1, hue=l1.X['labels_desc'], ax=ax[0])
sns.scatterplot(x=range(len(l2.X['depth'])),
                    y=l2.X['depth'] * -1, hue=l2.X['labels_desc'], ax=ax[1])
sns.scatterplot(x=range(len(l3.X['depth'])),
                    y=l3.X['depth'] * -1, hue=l3.X['labels_desc'], ax=ax[2])
fig.show()

print("Agglomerative Clustering Result:")
l1.classify()
print("\nSpectral Clustering Result:")
l2.classify()
print("\nK-Means Clustering Result:")
l3.classify()
# Out:
# Confidence of transit:  65.00%
# Checks passed fall within a lower range, transit possible but more analysis required.
# Confidence of transit:  65.00%
# Checks passed fall within a lower range, transit possible but more analysis required.
# Confidence of transit:  65.00%
# Checks passed fall within a lower range, transit possible but more analysis required.

# %% [markdown]
# ## CoRoT-2b - Weak Transit

# %%
# Agglomerative
l1 = Labeler(pd.read_csv('test/weak_transit.csv'))
l1.get_data()
agglom = l1.cluster_method(1)
l1.order_clusters(agglom)

# Spectral
l2 = Labeler(pd.read_csv('test/weak_transit.csv'))
l2.get_data()
spectral = l2.cluster_method(2)
l2.order_clusters(spectral)

# K-Means
l3 = Labeler(pd.read_csv('test/weak_transit.csv'))
l3.get_data()
kmeans = l3.cluster_method(3)
l3.order_clusters(kmeans)

# Graph clustering Methods
fig, ax = plt.subplots(1,3, figsize=(15,5), tight_layout=1)
ax[0].set(title="Agglomerative", xlabel="Epoch")
ax[1].set(title="Spectral", xlabel="Epoch")
ax[2].set(title="K-Means", xlabel="Epoch")
sns.scatterplot(x=range(len(l1.X['depth'])),
                    y=l1.X['depth'] * -1, hue=l1.X['labels_desc'], ax=ax[0])
sns.scatterplot(x=range(len(l2.X['depth'])),
                    y=l2.X['depth'] * -1, hue=l2.X['labels_desc'], ax=ax[1])
sns.scatterplot(x=range(len(l3.X['depth'])),
                    y=l3.X['depth'] * -1, hue=l3.X['labels_desc'], ax=ax[2])
fig.show()

print("Agglomerative Clustering Result:")
l1.classify()
print("\nSpectral Clustering Result:")
l2.classify()
print("\nK-Means Clustering Result:")
l3.classify()
# Out:
# Confidence of transit:  35.00%
# Less than half of the checks have passed, Transit not probable.
# Confidence of transit:  52.50%
# Checks passed fall within a lower range, transit possible but more analysis required.
# Confidence of transit:  45.00%
# Less than half of the checks have passed, Transit not probable.

# %% [markdown]
# ## Countplot of unique values

# %%
display(l1.X['labels_desc'].value_counts())
fig = plt.figure(figsize=(8,5))
sns.countplot(x='labels_desc',data = l1.X)
plt.title('Count of Unique Periods')
plt.show()
# Out:
# Exterior Egress     76
# Greatest Transit    61
# Exterior Ingress    45
# Interior Ingress    22
# Interior Egress      9
# Name: labels_desc, dtype: int64

# %% [markdown]
# ## Stats on Each Attribute

# %%
df = l1.X[[x for x in l1.X if x not in ['is_level', 'is_pos', 'is_neg', 'labels_int']]]
df.describe()
# Out:
#               epoch       depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# count  2.130000e+02  213.000000  213.000000       213.000000       213.000000
# mean   2.458008e+06    0.016342    0.973563         0.000971         0.973854
# std    5.357235e-02    0.000302    0.017985         0.007388         0.017550
# min    2.458008e+06    0.015629    0.931074        -0.024961         0.938083
# 25%    2.458008e+06    0.016174    0.963541        -0.003455         0.963839
# 50%    2.458008e+06    0.016284    0.970094         0.000357         0.970174
# 75%    2.458008e+06    0.016537    0.985166         0.005004         0.984114
# max    2.458008e+06    0.016945    1.009472         0.024663         1.004766
#
#        depth_prop_sma7  depth_prop_sma3_slope
# count       213.000000             213.000000
# mean          0.974414               0.000270
# std           0.017214               0.002390
# min           0.939073              -0.008320
# ...

# %% [markdown]
# ## Scatter and Distribution Plot of Each Attribute

# %%
for index, col in enumerate(df):
    if df[col].dtype != (object):
        fig, ax = plt.subplots(1,2, figsize=(12, 5), tight_layout=1)
        plt.title(col)
        sns.scatterplot(x=range(len(df[col])), y=df[col], ax=ax[0])
        sns.distplot(df[col], ax=ax[1])
        fig.show()
