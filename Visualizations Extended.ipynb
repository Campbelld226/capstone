# %% [markdown]
# # Visualizations

# %%
import pandas as pd
from Labeler import Labeler
import matplotlib.pyplot as plt 
import warnings
import seaborn as sns
import random
pd.options.display.max_rows = 999
warnings.filterwarnings('ignore')

# %% [markdown]
# # Clustering Algorithms

# %% [markdown]
# ## CoRoT-2b

# %%
# Agglomerative
l1 = Labeler(pd.read_csv('test/CoRoT-2b_1.6.csv'))
l1.get_data()
agglom = l1.cluster_method(1)
l1.order_clusters(agglom)

# Spectral
l2 = Labeler(pd.read_csv('test/CoRoT-2b_1.6.csv'))
l2.get_data()
spectral = l2.cluster_method(2)
l2.order_clusters(spectral)

# K-Means
l3 = Labeler(pd.read_csv('test/CoRoT-2b_1.6.csv'))
l3.get_data()
kmeans = l3.cluster_method(3)
l3.order_clusters(kmeans)

# Graph clustering Methods
fig, ax = plt.subplots(1,3, figsize=(15,5), tight_layout=1)
ax[0].set(title="Agglomerative", xlabel="Epoch")
ax[1].set(title="Spectral", xlabel="Epoch")
ax[2].set(title="K-Means", xlabel="Epoch")
sns.scatterplot(x=range(len(l1.X['depth'])),
                    y=l1.X['depth'] * -1, hue=l1.X['labels_desc'], ax=ax[0])
sns.scatterplot(x=range(len(l2.X['depth'])),
                    y=l2.X['depth'] * -1, hue=l2.X['labels_desc'], ax=ax[1])
sns.scatterplot(x=range(len(l3.X['depth'])),
                    y=l3.X['depth'] * -1, hue=l3.X['labels_desc'], ax=ax[2])
fig.show()

# %% [markdown]
# ## HAT-P-23b

# %%
# Agglomerative
l1 = Labeler(pd.read_csv('test/HAT-P-23b_1.2.csv'))
l1.get_data()
agglom = l1.cluster_method(1)
l1.order_clusters(agglom)

# Spectral
l2 = Labeler(pd.read_csv('test/HAT-P-23b_1.2.csv'))
l2.get_data()
spectral = l2.cluster_method(2)
l2.order_clusters(spectral)

# K-Means
l3 = Labeler(pd.read_csv('test/HAT-P-23b_1.2.csv'))
l3.get_data()
kmeans = l3.cluster_method(3)
l3.order_clusters(kmeans)

# Graph clustering Methods
fig, ax = plt.subplots(1,3, figsize=(15,5), tight_layout=1)
ax[0].set(title="Agglomerative", xlabel="Epoch")
ax[1].set(title="Spectral", xlabel="Epoch")
ax[2].set(title="K-Means", xlabel="Epoch")
sns.scatterplot(x=range(len(l1.X['depth'])),
                    y=l1.X['depth'] * -1, hue=l1.X['labels_desc'], ax=ax[0])
sns.scatterplot(x=range(len(l2.X['depth'])),
                    y=l2.X['depth'] * -1, hue=l2.X['labels_desc'], ax=ax[1])
sns.scatterplot(x=range(len(l3.X['depth'])),
                    y=l3.X['depth'] * -1, hue=l3.X['labels_desc'], ax=ax[2])
fig.show()

# %% [markdown]
# ## No Transit

# %%
# Agglomerative
l1 = Labeler(pd.read_csv('test/test.csv'))
l1.get_data()
agglom = l1.cluster_method(1)
l1.order_clusters(agglom)

# Spectral
l2 = Labeler(pd.read_csv('test/test.csv'))
l2.get_data()
spectral = l2.cluster_method(2)
l2.order_clusters(spectral)

# K-Means
l3 = Labeler(pd.read_csv('test/test.csv'))
l3.get_data()
kmeans = l3.cluster_method(3)
l3.order_clusters(kmeans)

# Graph clustering Methods
fig, ax = plt.subplots(1,3, figsize=(15,5), tight_layout=1)
ax[0].set(title="Agglomerative", xlabel="Epoch")
ax[1].set(title="Spectral", xlabel="Epoch")
ax[2].set(title="K-Means", xlabel="Epoch")
sns.scatterplot(x=range(len(l1.X['depth'])),
                    y=l1.X['depth'] * -1, hue=l1.X['labels_desc'], ax=ax[0])
sns.scatterplot(x=range(len(l2.X['depth'])),
                    y=l2.X['depth'] * -1, hue=l2.X['labels_desc'], ax=ax[1])
sns.scatterplot(x=range(len(l3.X['depth'])),
                    y=l3.X['depth'] * -1, hue=l3.X['labels_desc'], ax=ax[2])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 
.095,-0.000877\n96,2458000.096,-0.000829\n97,2458000.097,0.000499\n98,2458000.098,-5.1e-05\n99,2458000.099,-0.000704\n100,2458000.1,0.000354\n101,2458000.101,-0.000835\n102,2458000.102,0.000717\n103,2458000.103,-0.000451\n104,2458000.104,0.000955\n105,2458000.105,-0.00047\n106,2458000.106,0.000459\n107,2458000.107,-6.3e-05\n108,2458000.108,0.000313\n109,2458000.109,0.000866\n110,2458000.11,-0.000707\n111,2458000.111,-0.000897\n112,2458000.112,-0.00051\n113,2458000.113,-0.000161\n114,2458000.114,-0.000651\n115,2458000.115,-0.000728\n116,2458000.116,0.000413\n117,2458000.117,-0.000739\n118,2458000.118,-0.000521\n119,2458000.119,-0.000202\n120,2458000.12,0.000419\n121,2458000.121,0.000441\n122,2458000.122,0.00032\n123,2458000.123,-0.000935\n124,2458000.124,0.000975\n125,2458000.125,0.00054\n126,2458000.126,0.000695\n127,2458000.127,-5.5e-05\n128,2458000.128,0.000742\n129,2458000.129,0.000663\n130,2458000.13,-0.000428\n131,2458000.131,0.000397\n132,2458000.132,0.000928\n133,2458000.133,0.000386\n134,2458000.134,-0.000817\n135,2458000.135,0.000896\n136,2458000.136,-0.000521\n137,2458000.137,-0.000979\n138,2458000.138,0.000979\n139,2458000.139,-0.000902\n140,2458000.14,-0.000778\n141,2458000.141,-0.000348\n142,2458000.142,0.000923\n143,2458000.143,-0.000681\n144,2458000.144,0.000898\n145,2458000.145,-0.000386\n146,2458000.146,0.00098\n147,2458000.147,5.8e-05\n148,2458000.148,-0.000122\n149,2458000.149,-0.000903\n150,2458000.15,-0.000672\n151,2458000.151,0.000663\n152,2458000.152,-0.00015\n153,2458000.153,-0.000537\n154,2458000.154,0.000692\n155,2458000.155,-0.00078 ...

# %% [markdown]
# ## Countplot of unique values

# %%
display(l1.X['labels_desc'].value_counts())
fig = plt.figure(figsize=(8,5))
sns.countplot(x='labels_desc',data = l1.X)
plt.title('Count of Unique Periods')
# Out:
# Exterior Egress     76
# Greatest Transit    61
# Exterior Ingress    45
# Interior Ingress    22
# Interior Egress      9
# Name: labels_desc, dtype: int64
# Text(0.5, 1.0, 'Count of Unique Periods')

# %% [markdown]
# ## Stats on Each Attribute

# %%
df = l1.X[[x for x in l1.X if x not in ['is_level', 'is_pos', 'is_neg', 'labels_int']]]
df.describe()
# Out:
#               epoch       depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# count  2.130000e+02  213.000000  213.000000       213.000000       213.000000
# mean   2.458008e+06    0.016342    0.973563         0.000971         0.973854
# std    5.357235e-02    0.000302    0.017985         0.007388         0.017550
# min    2.458008e+06    0.015629    0.931074        -0.024961         0.938083
# 25%    2.458008e+06    0.016174    0.963541        -0.003455         0.963839
# 50%    2.458008e+06    0.016284    0.970094         0.000357         0.970174
# 75%    2.458008e+06    0.016537    0.985166         0.005004         0.984114
# max    2.458008e+06    0.016945    1.009472         0.024663         1.004766
#
#        depth_prop_sma7  depth_prop_sma3_slope
# count       213.000000             213.000000
# mean          0.974414               0.000270
# std           0.017214               0.002390
# min           0.939073              -0.008320
# 25%           0.963890              -0.001152
# 50%           0.969481               0.000099
# 75%           0.984290               0.001648
# max           1.003336               0.007725

# %% [markdown]
# ## Scatter and Distribution Plot of Each Attribute

# %%
for index, col in enumerate(df):
    if df[col].dtype != (object):
        fig, ax = plt.subplots(1,2, figsize=(12, 5), tight_layout=1)
        plt.title(col)
        sns.scatterplot(x=range(len(df[col])), y=df[col], ax=ax[0])
        sns.distplot(df[col], ax=ax[1])
        fig.show()
