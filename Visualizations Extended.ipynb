# %% [markdown]
# # Visualizations

# %%
import pandas as pd
from Labeler import Labeler

# %%
l = Labeler(pd.read_csv('real_data/AdrienneS_comps.csv'))
df = l.get_cluster()

# %% [markdown]
# # Countplot of unique values

# %%
display(df['labels_desc'].value_counts())
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,5))
sns.countplot(x='labels_desc',data = df)
plt.title('Count of Unique Periods')
# Out:
# Post Transit      151
# Bottom             29
# Pre Transit        18
# Downward Slope     12
# Upward Slope       12
# Name: labels_desc, dtype: int64
# Text(0.5, 1.0, 'Count of Unique Periods')

# %%
df.head()
# Out:
#            epoch     depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# 6   2.457128e+06  99.99999 -141.201042         0.000000      -141.201042
# 7   2.457128e+06  99.99999 -141.201042         0.000000      -141.201042
# 8   2.457128e+06  99.99999 -141.201042         0.000000      -141.201042
# 9   2.457128e+06  99.99999 -141.201042         0.000000      -141.201042
# 10  2.457128e+06  99.99999 -141.201042      -142.290507      -141.201042
#
#     depth_prop_sma7  depth_prop_sma3_slope  is_level  is_neg  is_pos  \
# 6       -120.886607                    0.0         1       0       0
# 7       -141.201042                    0.0         1       0       0
# 8       -141.201042                    0.0         1       0       0
# 9       -141.201042                    0.0         1       0       0
# 10      -141.201042                    0.0         1       0       0
#
#     labels_int color labels_desc
# 6            0   red      Bottom
# 7            0   red      Bottom
# 8            0   red      Bottom
# 9            0   red      Bottom
# 10           0   red      Bottom

# %%
df.describe()
# Out:
#               epoch       depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# count  2.220000e+02  222.000000  222.000000     2.220000e+02       222.000000
# mean   2.457128e+06   20.592153  -29.076337    -3.840772e-16       -29.076337
# std    4.885019e-02   41.245222   58.238689     5.413313e+01        49.143512
# min    2.457128e+06   -0.801710 -141.201042    -1.423331e+02      -141.201042
# 25%    2.457128e+06   -0.739633    1.013386    -4.998517e-03       -46.378085
# 50%    2.457128e+06   -0.727815    1.027682     0.000000e+00         1.024776
# 75%    2.457128e+06   -0.717690    1.044369     7.162424e-03         1.038177
# max    2.457128e+06   99.999990    1.132023     1.423331e+02         1.098963
#
#        depth_prop_sma7  depth_prop_sma3_slope    is_level      is_neg  \
# count       222.000000           2.220000e+02  222.000000  222.000000
# mean        -28.984830           3.200643e-17    0.855856    0.072072
# std          44.945090           1.804438e+01    0.352030    0.259192
# min        -141.201042          -4.744436e+01    0.000000    0.000000
# 25%         -39.608382          -1.666172e-03    1.000000    0.000000
# 50%           1.000155           0.000000e+00    1.000000    0.000000
# 75%           1.027741           2.387475e-03    1.000000    0.000000
# max           1.055131           4.744436e+01    1.000000    1.000000
#
#            is_pos  labels_int
# count  222.000000  222.000000
# mean     0.072072    1.900901
# std      0.259192    0.974377
# min      0.000000    0.000000
# 25%      0.000000    2.000000
# 50%      0.000000    2.000000
# 75%      0.000000    2.000000
# max      1.000000    4.000000

# %%
import matplotlib.pyplot as plt 
for col in df:
    if df[col].dtype != (object):
        sns.distplot(df[col])
        plt.show()
        sns.scatterplot(x=range(len(df[col])), y=df[col])
        plt.show()
