# %% [markdown]
# # Visualizations

# %%
import pandas as pd
from Labeller import Labeller

# %%
l = Labeller(pd.read_csv('test/CoRoT-2b_1.7.txt'))
df = l.get_cluster()
# Out:
# /home/dylan/Documents/capstone/Labeller.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['depth_prop'] = train_data['depth'] / train_data['depth'].values[0]

# %% [markdown]
# # Countplot of unique values

# %%
display(df['labels_desc'].value_counts())
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,5))
sns.countplot(x='labels_desc',data = df)
plt.title('Count of Unique Periods')
# Out:
# Bottom            44
# Post Transit       8
# Upward Slope       8
# Pre Transit        6
# Downward Slope     6
# Name: labels_desc, dtype: int64
# Text(0.5, 1.0, 'Count of Unique Periods')

# %%
df.head()
# Out:
#            epoch    depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# 6   2.457920e+06  0.23830    0.952172        -0.003157         0.955861
# 7   2.457920e+06  0.24362    0.973429        -0.012427         0.958205
# 8   2.457920e+06  0.24084    0.962321        -0.018340         0.962640
# 9   2.457920e+06  0.23909    0.955328        -0.065769         0.963693
# 10  2.457920e+06  0.24673    0.985855        -0.054981         0.967835
#
#     depth_prop_sma7  depth_prop_sma3_slope  is_level  is_neg  is_pos  \
# 6          0.972555              -0.002344         1       0       0
# 7          0.968759              -0.004435         1       0       0
# 8          0.966950              -0.001052         1       0       0
# 9          0.961014              -0.004142         1       0       0
# 10         0.963502              -0.006113         1       0       0
#
#     labels_int   color  labels_desc
# 6            4  yellow  Pre Transit
# 7            4  yellow  Pre Transit
# 8            4  yellow  Pre Transit
# 9            4  yellow  Pre Transit
# 10           4  yellow  Pre Transit

# %%
df.describe()
# Out:
#               epoch      depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# count  7.200000e+01  72.000000   72.000000        72.000000        72.000000
# mean   2.457920e+06   0.269782    1.077962        -0.000834         1.077605
# std    3.079645e-02   0.013991    0.055904         0.023902         0.055920
# min    2.457920e+06   0.238300    0.952172        -0.066648         0.955861
# 25%    2.457920e+06   0.260692    1.041645        -0.009200         1.037912
# 50%    2.457920e+06   0.277075    1.107104        -0.002337         1.105499
# 75%    2.457921e+06   0.279875    1.118292         0.011198         1.119228
# max    2.457921e+06   0.284710    1.137611         0.060095         1.133536
#
#        depth_prop_sma7  depth_prop_sma3_slope  is_level  is_neg  is_pos  \
# count        72.000000              72.000000      72.0    72.0    72.0
# mean          1.077377              -0.000355       1.0     0.0     0.0
# std           0.054786               0.007974       0.0     0.0     0.0
# min           0.961014              -0.022216       1.0     0.0     0.0
# 25%           1.039255              -0.003197       1.0     0.0     0.0
# 50%           1.105443              -0.000939       1.0     0.0     0.0
# 75%           1.119898               0.003733       1.0     0.0     0.0
# max           1.128804               0.020032       1.0     0.0     0.0
#
#        labels_int
# count   72.000000
# mean     0.916667
# std      1.350535
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      2.000000
# max      4.000000

# %%
import matplotlib.pyplot as plt 
for col in df:
    if df[col].dtype != (object):
        sns.distplot(df[col])
        plt.show()
        sns.scatterplot(x=range(len(df[col])), y=df[col])
        plt.show()
# Out:
# /home/dylan/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/dylan/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
