# %% [markdown]
# # Visualizations

# %%
import pandas as pd
import numpy as np
from Labeler import Labeler

# %%
l = Labeler(pd.read_csv('real_data/AdrienneS_comps.csv'))
df = l.get_cluster()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Countplot of unique values

# %%
display(df['labels_desc'].value_counts())
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,5))
sns.countplot(x='labels_desc',data = df)
plt.title('Count of Unique Periods')
# Out:
# Bottom            60
# Upward Slope      47
# Downward Slope    27
# Pre Transit       25
# Post Transit       8
# Name: labels_desc, dtype: int64
# Text(0.5, 1.0, 'Count of Unique Periods')

# %%
df.head()
# Out:
#            epoch    depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# 6   2.457128e+06 -0.77904    1.100013         0.015320         1.084434
# 7   2.457128e+06 -0.79301    1.119738         0.017721         1.108231
# 8   2.457128e+06 -0.77369    1.092458         0.016478         1.104070
# 9   2.457128e+06 -0.76819    1.084692         0.015334         1.098963
# 10  2.457128e+06 -0.78046    1.102018         0.053303         1.093056
#
#     depth_prop_sma7  depth_prop_sma3_slope  is_level  is_neg  is_pos  \
# 6          1.073447              -0.023797         1       0       0
# 7          1.090552               0.004161         1       0       0
# 8          1.090980               0.005107         1       0       0
# 9          1.090296               0.005907         1       0       0
# 10         1.093173               0.005493         1       0       0
#
#     labels_int  color   labels_desc
# 6            2  green  Post Transit
# 7            2  green  Post Transit
# 8            2  green  Post Transit
# 9            2  green  Post Transit
# 10           2  green  Post Transit

# %%
df.describe()
# Out:
#               epoch       depth  depth_prop  depth_prop_diff  depth_prop_sma3  \
# count  1.670000e+02  167.000000  167.000000       167.000000       167.000000
# mean   2.457128e+06   -0.733398    1.035565         0.000979         1.035823
# std    3.978430e-02    0.014683    0.020732         0.018600         0.019243
# min    2.457128e+06   -0.801710    0.989664        -0.110151         0.990516
# 25%    2.457128e+06   -0.740875    1.024244        -0.004999         1.024917
# 50%    2.457128e+06   -0.730700    1.031756         0.000071         1.030570
# 75%    2.457128e+06   -0.725380    1.046123         0.008063         1.046653
# max    2.457128e+06   -0.700890    1.132023         0.107412         1.108231
#
#        depth_prop_sma7  depth_prop_sma3_slope  is_level  is_neg  is_pos  \
# count       167.000000             167.000000     167.0   167.0   167.0
# mean          1.036080               0.000229       1.0     0.0     0.0
# std           0.018156               0.006478       0.0     0.0     0.0
# min           0.993862              -0.036717       1.0     0.0     0.0
# 25%           1.025449              -0.001666       1.0     0.0     0.0
# 50%           1.030576               0.000075       1.0     0.0     0.0
# 75%           1.047225               0.002695       1.0     0.0     0.0
# max           1.097120               0.035804       1.0     0.0     0.0
#
#        labels_int
# count  167.000000
# mean     1.461078
# std      1.483843
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      3.000000
# max      4.000000

# %%
import matplotlib.pyplot as plt 
for col in df:
    if df[col].dtype != (object):
        sns.distplot(df[col])
        plt.show()
        sns.scatterplot(x=range(len(df[col])), y=df[col])
        plt.show()
# Out:
# /home/dylan/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/dylan/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
